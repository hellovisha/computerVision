# %% [markdown]
# # 🎯 What is Computer Vision?
#
# ##### Imagine you have a robot friend 🧑‍🤖. You give them eyes (a camera), and now they can see the world. But… they don’t understand what they’re seeing. It all looks like a bunch of numbers (pixels) to them!

# %% [markdown]
# ## Computer vision is the magic ✨ that teaches the robot to understand
#
#
#  1. "Oh, that's a cat 🐱!"
#
#  2. "That’s a stop sign 🚦!"
#
#  3. "This person looks happy 😄!"
#
#  4. "There are 3 people in this photo."

# %% [markdown]
# #### Example !
#
#
# ` Take your phone. When you `
#
# - - Unlock with your face 👤 → that’s computer vision.
#
# - - Add filters to your selfies 😎 → that’s computer vision.
#
# - - Scan a QR code 📱 → yup, also computer vision.
#
# - - Google Lens identifying a plant 🌿 also computer vision.

# %% [markdown]
# # 🛠 How Does It Work?
#
# `Behind the scenes `
#
# - - It sees the image as pixels (numbers from 0 to 255).
#
# - - It finds patterns: edges, shapes, colors.
#
# - - It uses algorithms (like CNNs) to make smart guesses.

# %% [markdown]
# ### what is the  difference between a Neural Network (NN) and a Convolutional Neural Network (CNN) ?

# %% [markdown]
# ## `🍩 1. Neural Networks (NN) – The General Thinker`
#
#
#
#
# `A Neural Network is a general-purpose brain-like system. It works well with:`
#
# - - Numbers
#
# - - Tabular data (like Excel sheets)
#
# - - Simple patterns
#
# 🧠 Example:
# You give it:
#
# Height, Weight → Predicts if a person is fit
#
# But it doesn’t understand images very well because images are BIG (millions of pixels) and have spatial structure (neighboring pixels matter).

# %% [markdown]
# ## `🖼️ 2. Convolutional Neural Networks (CNN) – The Visual Expert`
#
# `A CNN is a special kind of neural network designed for images.`
#
# It’s like a neural network with eyes 👀.
#
# `What it does differently:`
# - - Uses filters (tiny windows) to look at small parts of the image
#
# - - Detects patterns like edges, corners, and shapes
#
# - - Builds up from simple features to complex ones (like a face!)

# %% [markdown]
# | Feature                   | Neural Network (NN)         | Convolutional Neural Network (CNN) |
# | ------------------------- | --------------------------- | ---------------------------------- |
# | Input type                | Numbers / Tabular data      | Images / Grid-like data            |
# | Layers used               | Dense (Fully Connected)     | Convolution + Pooling + Dense      |
# | Understands images?       | Not really                  | Yes! Specialized for images        |
# | Preserves image structure | ❌ No                        | ✅ Yes                            |
# | Example task              | Predict price from features | Recognize a cat in an image        |

# %% [markdown]
#  # How CNNs are inspired by the human brain’s visual cortex ?
#
# - - `In your brain, there’s a special region at the back of your head called the visual cortex. This part is like your brain’s image processing center`
#
#
# #### `What it does:`
#
# - 1. Detects edges, colors, shapes
#
# - 2. Understands depth, motion, faces
#
# - 3 .Builds a picture from parts to whole (eye → face → person)
#
# It doesn’t just look at the whole image at once — it analyzes it piece by piece, layer by layer.

# %% [markdown]
# <img src= "https://d2jx2rerrg6sh3.cloudfront.net/image-handler/picture/2021/10/shutterstock_166610156-1.jpg" >

# %% [markdown]
# <img src = "https://www.researchgate.net/publication/282601766/figure/fig3/AS:904130172309505@1592572839301/sual-cortex-region-shown-in-human-brain-source-2.jpg" />

# %% [markdown]
# ## `🔬 Real-World Inspiration `
# In 1962, neuroscientists Hubel and Wiesel discovered that cats' visual cortex neurons fired for edges and orientations. That’s how early CNNs were designed—mimicking those biological filters.

# %% [markdown]
# ### ` 🔍 Main Visual Areas and Their Functions `

# %% [markdown]
# | Brain Area                     | Function 🎯                                    | Analogy in CNNs 🖥️                                           |
# | ------------------------------ | ---------------------------------------------- | ------------------------------------------------------------- |
# | **V1 (Primary Visual Cortex)** | Detects **edges**, **lines**, **orientations** | First convolutional layer (edge detectors)                    |
# | **V2**                         | Detects **textures**, **simple shapes**        | Deeper filters detecting corners, patterns                    |
# | **V3**                         | Understands **motion** & **form**              | Motion-aware or temporal filters (like in video CNNs)         |
# | **V4**                         | Handles **color** and **complex shapes**       | Color-aware models / complex feature maps                     |
# | **IT (Inferotemporal cortex)** | Recognizes **faces**, **objects**, **scenes**  | Final dense layers or specialized CNN heads (e.g., YOLO head) |
# | **MT/V5**                      | Specialized for **motion detection**           | Optical flow models or 3D CNNs for video                      |

# %% [markdown]
# ## `What is an Image?`
#
# - -  An image on your computer or phone is basically a grid of tiny dots
# - -  Each tiny dot in that grid is called a pixel

# %% [markdown]
# # ` 🔍 What is a Pixel?  `
#
# 1. A pixel is the smallest unit of an image.
#
# 2. It holds color information.
#
# 3. Think of pixels as tiny colored squares that, when put together, form the full picture.

# %% [markdown]
# < img src = "https://ai.stanford.edu/~syyeung/cvweb/Pictures1/imagematrix.png" />

# %%
import cv2
import matplotlib.pyplot as plt

# Load The image

image  = cv2.imread('1.jpg')


# Convert BGR to RGB (Matplotlib uses RGB)
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# Display the image with grid 
plt.figure(figsize = (8,8))
plt.imshow(image_rgb)
plt.show()

# %% [markdown]
# # grayscale images and RGB images

# %% [markdown]
# ### `🎨 RGB Image`

# %% [markdown]
# ### ` ✅ What is it? `
# `A colored image made up of 3 channels:`
#
# - - Red
#
# - - Green
#
# - - Blue
#
# - ✅ Total data:
# Height x Width x 3 values

# %% [markdown]
# ## `⚫ Grayscale Image`
#
# `✅ What is it?`
#
# A black-and-white image with just 1 channel.
#
# Each pixel is a single value (0 = black, 255 = white, values in between = shades of gray).
#
# `✅ Structure:`
# Image shape: (height, width)

# %% [markdown]
# | Feature       | RGB Image            | Grayscale Image           |
# | ------------- | -------------------- | ------------------------- |
# | Channels      | 3 (Red, Green, Blue) | 1 (Gray)                  |
# | File Size     | Larger               | Smaller                   |
# | Color Info    | Full color           | No color (intensity only) |
# | Shape in code | `(H, W, 3)`          | `(H, W)`                  |
